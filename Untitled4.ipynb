# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
worldcup=pd.read_csv('WorldCupMatches.csv')

# %%
worldcup.head(5)
# Out:
#    Unnamed: 0        City       State
# 0           0  Sacramento  California
# 1           1       Miami     Florida

# %%
wines = np.genfromtxt("WorldCupMatches.csv", delimiter=";", skip_header=1)

# %%
col_names = ['Id',
             'Survived',
             'Passenger Class',
             'Full Name',
             'Gender',
             'Age',
             'SibSp',
             'Parch',
             'Ticket Number',
             'Price', 'Cabin',
             'Station']

titanic_data = pd.read_csv("WorldCupMatches.csv", names=col_names)
print(titanic_data.head())
# Out:
#     Id    Survived Passenger Class  Full Name  Gender  Age  SibSp  Parch  \
# 0  NaN        City           State        NaN     NaN  NaN    NaN    NaN
# 1  0.0  Sacramento      California        NaN     NaN  NaN    NaN    NaN
# 2  1.0       Miami         Florida        NaN     NaN  NaN    NaN    NaN
#
#    Ticket Number  Price  Cabin  Station
# 0            NaN    NaN    NaN      NaN
# 1            NaN    NaN    NaN      NaN
# 2            NaN    NaN    NaN      NaN

# %%
titanic_data = pd.read_csv("WorldCupMatches.csv", header=None, skiprows=[0])

# %%
titanic_data.head(5)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
cities = pd.DataFrame([['Sacramento', 'California'], ['Miami', 'Florida']], columns=['City', 'State'])
cities.to_csv("WorldCupMatches.csv")

# %%
cities.head(5)
# Out:
#          City       State
# 0  Sacramento  California
# 1       Miami     Florida

# %%
worldcup.head(5)
# Out:
#    Unnamed: 0        City       State
# 0           0  Sacramento  California
# 1           1       Miami     Florida

# %%
df = pd.read_csv("WorldCupMatches.csv")
print(df)
# Out:
#    Unnamed: 0        City       State
# 0           0  Sacramento  California
# 1           1       Miami     Florida

# %%
pd.read_csv('WorldCupMatches.csv', delimiter=';')
# Out:
#                ,City,State
# 0  0,Sacramento,California
# 1          1,Miami,Florida

# %%
titanic_data = pd.read_csv("worldCuppMatches.csv")
print(titanic_data.head(5))
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
titanic_data.head(10)
# Out:
#      Year              Datetime    Stage             Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1             Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4      Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7  1930.0  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8  1930.0  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9  1930.0  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# ...

# %%
np.genfromtxt('WorldCupMatches.csv',delimiter=',')
# Out:
# array([[nan, nan, nan],
#        [ 0., nan, nan],
#        [ 1., nan, nan]])

# %%
file_data = open('WorldCupMatches.csv')
for row in file_data:
    print(row)
# Out:
# ,City,State
#
# 0,Sacramento,California
#
# 1,Miami,Florida

# %%
with open('worldCuppMatches.csv', 'r') as f:
    data = list(csv.reader(f, delimiter=";")) 
data = np.array(data)
print(data)
# Out:
# [['Year,Datetime,Stage,Stadium,City,Home Team Name,Home Team Goals,Away Team Goals,Away Team Name,Win conditions,Attendance,Half-time Home Goals,Half-time Away Goals,Referee,Assistant 1,Assistant 2,RoundID,MatchID,Home Team Initials,Away Team Initials']
#  ['1930,"13 Jul 1930 - 15:00 ",Group 1,Pocitos,"Montevideo ",France,4,1,Mexico," ",4444,3,0,LOMBARDI Domingo (URU),CRISTOPHE Henry (BEL),REGO Gilberto (BRA),201,1096,FRA,MEX']
#  ['1930,"13 Jul 1930 - 15:00 ",Group 4,Parque Central,"Montevideo ",USA,3,0,Belgium," ",18346,2,0,MACIAS Jose (ARG),MATEUCCI Francisco (URU),WARNKEN Alberto (CHI),201,1090,USA,BEL']
#  ...
#  [',,,,,,,,,,,,,,,,,,,']
#  [',,,,,,,,,,,,,,,,,,,']
#  [',,,,,,,,,,,,,,,,,,,']]

# %%
from pandas import read_csv
df = read_csv('worldCuppMatches.csv')
data = df.values
print(data)
# Out:
# [[1930.0 '13 Jul 1930 - 15:00 ' 'Group 1' ... 1096.0 'FRA' 'MEX']
#  [1930.0 '13 Jul 1930 - 15:00 ' 'Group 4' ... 1090.0 'USA' 'BEL']
#  [1930.0 '14 Jul 1930 - 12:45 ' 'Group 2' ... 1093.0 'YUG' 'BRA']
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
file = open('WorldCupMatches.csv')
csv_reader = csv.reader(file)
next(csv_reader) 
for row in csv_reader:
    print(row)
# Out:
# ['0', 'Sacramento', 'California']
# ['1', 'Miami', 'Florida']

# %%
file_data = open("WorldCupMatches.csv")
reader = csv.reader(file_data)
Count_lines= len(list(reader))
print(Count_lines)
# Out:
# 3

# %%
file_data = open("worldCuppMatches.csv")
reader = csv.reader(file_data)
Count_lines= len(list(reader))
print(Count_lines)
# Out:
# 4573

# %%
pop = pd.read_csv("WorldCupMatches.csv", 
                  header=None,
                  names=["Country", "Population"],
                  index_col=0,
                  quotechar="'", 
                  sep=" ", 
                  thousands=",")
print(pop.head(5))
# Out:
#                          Population
# Country
# ,City,State                     NaN
# 0,Sacramento,California         NaN
# 1,Miami,Florida                 NaN

# %%
worldcupp=pd.read_csv('worldCuppMatches.csv')

# %%
worldcupp.head(3)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# ...
